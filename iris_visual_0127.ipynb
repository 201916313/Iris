# %%
import numpy as np 
import pandas as pd

# %%
iris ="C:/Users/byeongwan/OneDrive/desktop/archive/Iris.csv"
data = pd.read_csv(iris, index_col=['Id'])
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df=data.drop(columns=['Species'])
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Id
# 1              5.1           3.5            1.4           0.2
# 2              4.9           3.0            1.4           0.2
# 3              4.7           3.2            1.3           0.2
# 4              4.6           3.1            1.5           0.2
# 5              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 146            6.7           3.0            5.2           2.3
# 147            6.3           2.5            5.0           1.9
# 148            6.5           3.0            5.2           2.0
# 149            6.2           3.4            5.4           2.3
# 150            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,5))
plt.title("Comprisons")
sns.lineplot(data=df)
plt.ylabel("length")
# Out:
# Text(0, 0.5, 'length')

# %%
plt.figure(figsize=(12,5))
plt.title("sepal_Length species vice")
sns.barplot(x=data.Species,y=data.SepalLengthCm)
# Out:
# <AxesSubplot:title={'center':'sepal_Length species vice'}, xlabel='Species', ylabel='SepalLengthCm'>

# %%
plt.figure(figsize=(12,7))
plt.title("Sepal length vs Petal length")
sns.scatterplot(x=data.SepalLengthCm,y=data.PetalLengthCm)
# Out:
# <AxesSubplot:title={'center':'Sepal length vs Petal length'}, xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
plt.figure(figsize=(12,8))
plt.title("Petal lenth vs Sepal length on Species")
sns.scatterplot(x=data.SepalLengthCm,y=data.PetalLengthCm,hue=data.Species)
# Out:
# <AxesSubplot:title={'center':'Petal lenth vs Sepal length on Species'}, xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
plt.figure(figsize=(12,6))
plt.title("Sepal length vs sepal width")
sns.regplot(x=data.SepalLengthCm,y=data.SepalWidthCm)
# Out:
# <AxesSubplot:title={'center':'Sepal length vs sepal width'}, xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
sns.lmplot(x='PetalLengthCm',y='PetalWidthCm',hue='Species',data=data)

# %%
sns.lmplot(x='SepalLengthCm',y='PetalLengthCm',hue='Species',data=data)

# %%
sns.swarmplot(x=data.SepalLengthCm,y=data.Species)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Species'>

# %%
plt.figure(figsize=(12,7))
plt.title("Variance of Sepal Length")
sns.kdeplot(data=data.SepalLengthCm,shade=True)
plt.xlabel("length")
plt.ylabel('Variance')
# Out:
# C:\Users\BYEONG~1\AppData\Local\Temp/ipykernel_9020/3190593133.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=data.SepalLengthCm,shade=True)
# Text(0, 0.5, 'Variance')

# %%
plt.figure(figsize=(12,8))
plt.title("Variance of Sepal Length")
sns.distplot(a=data.SepalWidthCm,kde=False)
plt.ylabel("limit")
# Out:
# C:\Users\BYEONG~1\AppData\Local\Temp/ipykernel_9020/3161659448.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=data.SepalWidthCm,kde=False)
# Text(0, 0.5, 'limit')

# %%
sns.jointplot(x=data.SepalLengthCm,y=data.PetalLengthCm,kind='kde')
print("Variance of PetalLength is very high it may be result in overfiting of model")
# Out:
# Variance of PetalLength is very high it may be result in overfiting of model
